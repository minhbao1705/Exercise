# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/drive/MyDrive/creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
rows,cols=df.shape
print(f'There are {rows} Rows and {cols} Columns')
# Out:
# There are 284807 Rows and 31 Columns

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.654067e-16 -3.568593e-16  2.578648e-16  4.473266e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.340915e-16  1.683437e-15 -3.660091e-16 -1.227390e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
data_corr=df.corr().style.background_gradient(cmap='twilight')
data_corr
# Out:
# <style type="text/css">
# #T_9c402_row0_col0, #T_9c402_row0_col3, #T_9c402_row0_col4, #T_9c402_row0_col6, #T_9c402_row0_col11, #T_9c402_row0_col13, #T_9c402_row0_col15, #T_9c402_row0_col20, #T_9c402_row0_col24, #T_9c402_row0_col25, #T_9c402_row0_col26, #T_9c402_row0_col27, #T_9c402_row0_col28, #T_9c402_row1_col1, #T_9c402_row1_col21, #T_9c402_row2_col2, #T_9c402_row2_col21, #T_9c402_row2_col29, #T_9c402_row3_col0, #T_9c402_row3_col3, #T_9c402_row3_col21, #T_9c402_row4_col4, #T_9c402_row4_col21, #T_9c402_row5_col5, #T_9c402_row5_col21, #T_9c402_row6_col6, #T_9c402_row6_col21, #T_9c402_row7_col7, #T_9c402_row7_col21, #T_9c402_row8_col8, #T_9c402_row8_col21, #T_9c402_row9_col9, #T_9c402_row9_col21, #T_9c402_row10_col10, #T_9c402_row10_col21, #T_9c402_row11_col11, #T_9c402_row11_col21, #T_9c402_row12_col12, #T_9c402_row12_col21, #T_9c402_row13_col13, #T_9c402_row13_col21, #T_9c402_row14_col14, #T_9c402_row14_col21, #T_9c402_row15_col15, #T_9c402_row15_col21, #T_9c402_row16_col16, #T_9c402_row16_col21, #T_9c402_row17_col17, #T_9c402_row17_col21, #T_9c402_row17_col30, #T_9c402_row18_col18, #T_9c402_row18_col21, #T_9c402_row19_col19, #T_9c402_row19_col21, #T_9c402_row20_col20, #T_9c402_row20_col21, #T_9c402_row21_col21, #T_9c402_row22_col21, #T_9c402_row22_col22, #T_9c402_row23_col21, #T_9c402_row23_col23, #T_9c402_row24_col21, #T_9c402_row24_col24, #T_9c402_row25_col21, #T_9c402_row25_col25, #T_9c402_row26_col21, #T_9c402_row26_col26, #T_9c402_row27_col21, #T_9c402_row27_col27, #T_9c402_row28_col21, #T_9c402_row28_col28, #T_9c402_row29_col1, #T_9c402_row29_col2, #T_9c402_row29_col5, #T_9c402_row29_col8, #T_9c402_row29_col19, #T_9c402_row29_col22, #T_9c402_row29_col23, #T_9c402_row29_col29, #T_9c402_row30_col7, #T_9c402_row30_col9, #T_9c402_row30_col10, #T_9c402_row30_col12, #T_9c402_row30_col14, #T_9c402_row30_col16, #T_9c402_row30_col17, #T_9c402_row30_col18, #T_9c402_row30_col30 {
#   background-color: #e2d9e2;
#   color: #000000;
# }
# #T_9c402_row0_col1, #T_9c402_row10_col29 {
#   background-color: #5f64b5;
#   color: #f1f1f1;
# }
# #T_9c402_row0_col2, #T_9c402_row0_col29, #T_9c402_row12_col29 {
#   background-color: #5d40a2;
#   color: #f1f1f1;
# }
# #T_9c402_row0_col5 {
#   background-color: #531d7a;
#   color: #f1f1f1;
# }
# #T_9c402_row0_col7 {
#   background-color: #6682bd;
#   color: #f1f1f1;
# }
# #T_9c402_row0_col8, #T_9c402_row1_col6, #T_9c402_row2_col6, #T_9c402_row3_col6, #T_9c402_row4_col6, #T_9c402_row5_col6, #T_9c402_row7_col6, #T_9c402_row8_col6, #T_9c402_row9_col6, #T_9c402_row10_col6, #T_9c402_row11_col6, #T_9c402_row12_col6, #T_9c402_row13_col6, #T_9c402_row14_col6, #T_9c402_row15_col6, #T_9c402_row16_col6, #T_9c402_row17_col6, #T_9c402_row18_col6, #T_9c402_row19_col6, #T_9c402_row20_col6, #T_9c402_row21_col6, #T_9c402_row22_col6, #T_9c402_row23_col6, #T_9c402_row24_col6, #T_9c402_row25_col6, #T_9c402_row26_col6, #T_9c402_row27_col6, #T_9c402_row28_col6 {
#   background-color: #c5cfd5;
#   color: #000000;
# }
# #T_9c402_row0_col9, #T_9c402_row0_col19 {
#   background-color: #b5c7cf;
#   color: #000000;
# }
# #T_9c402_row0_col10 {
#   background-color: #6c8fbf;
#   color: #f1f1f1;
# }
# #T_9c402_row0_col12, #T_9c402_row16_col0, #T_9c402_row22_col29 {
#   background-color: #5f55af;
#   color: #f1f1f1;
# }
# #T_9c402_row0_col14, #T_9c402_row1_col15, #T_9c402_row2_col15, #T_9c402_row3_col15, #T_9c402_row4_col15, #T_9c402_row5_col15, #T_9c402_row6_col15, #T_9c402_row7_col15, #T_9c402_row8_col15, #T_9c402_row9_col15, #T_9c402_row10_col15, #T_9c402_row11_col15, #T_9c402_row12_col15, #T_9c402_row13_col15, #T_9c402_row14_col15, #T_9c402_row16_col15, #T_9c402_row17_col15, #T_9c402_row18_col15, #T_9c402_row19_col15, #T_9c402_row20_col15, #T_9c402_row21_col15, #T_9c402_row22_col15, #T_9c402_row23_col15, #T_9c402_row24_col15, #T_9c402_row25_col15, #T_9c402_row26_col15, #T_9c402_row27_col15, #T_9c402_row28_col15 {
#   background-color: #81a6c3;
#   color: #f1f1f1;
# }
# #T_9c402_row0_col16 {
#   background-color: #789ec2;
#   color: #f1f1f1;
# }
# #T_9c402_row0_col17, #T_9c402_row30_col25 {
#   background-color: #7195c0;
#   color: #f1f1f1;
# }
# #T_9c402_row0_col18 {
#   background-color: #759ac1;
#   color: #f1f1f1;
# }
# #T_9c402_row0_col21, #T_9c402_row30_col26 {
#   background-color: #d0d4d9;
#   color: #000000;
# }
# #T_9c402_row0_col22 {
#   background-color: #6e92c0;
#   color: #f1f1f1;
# }
# #T_9c402_row0_col23 {
#   background-color: #86aac4;
#   color: #f1f1f1;
# }
# #T_9c402_row0_col30 {
#   background-color: #647dbc;
#   color: #f1f1f1;
# }
# #T_9c402_row1_col0 {
#   background-color: #59298e;
#   color: #f1f1f1;
# }
# #T_9c402_row1_col2, #T_9c402_row3_col2, #T_9c402_row4_col2, #T_9c402_row4_col30, #T_9c402_row5_col2, #T_9c402_row6_col2, #T_9c402_row7_col2, #T_9c402_row8_col2, #T_9c402_row9_col2, #T_9c402_row10_col2, #T_9c402_row11_col2, #T_9c402_row12_col2, #T_9c402_row13_col2, #T_9c402_row14_col2, #T_9c402_row15_col2, #T_9c402_row16_col2, #T_9c402_row17_col2, #T_9c402_row18_col2, #T_9c402_row19_col2, #T_9c402_row20_col2, #T_9c402_row21_col2, #T_9c402_row22_col2, #T_9c402_row23_col2, #T_9c402_row24_col2, #T_9c402_row25_col2, #T_9c402_row26_col2, #T_9c402_row27_col2, #T_9c402_row28_col2 {
#   background-color: #5d3ca0;
#   color: #f1f1f1;
# }
# #T_9c402_row1_col3, #T_9c402_row2_col3, #T_9c402_row4_col3, #T_9c402_row5_col3, #T_9c402_row6_col3, #T_9c402_row7_col3, #T_9c402_row8_col3, #T_9c402_row9_col3, #T_9c402_row10_col3, #T_9c402_row11_col3, #T_9c402_row12_col3, #T_9c402_row13_col3, #T_9c402_row14_col3, #T_9c402_row15_col3, #T_9c402_row16_col3, #T_9c402_row17_col3, #T_9c402_row18_col3, #T_9c402_row19_col3, #T_9c402_row20_col3, #T_9c402_row21_col3, #T_9c402_row22_col3, #T_9c402_row23_col3, #T_9c402_row24_col3, #T_9c402_row25_col3, #T_9c402_row26_col3, #T_9c402_row27_col3, #T_9c402_row28_col3 {
#   background-color: #5f5bb2;
#   color: #f1f1f1;
# }
# #T_9c402_row1_col4, #T_9c402_row2_col4, #T_9c402_row3_col4, #T_9c402_row5_col4, #T_9c402_row5_col29, #T_9c402_row6_col4, #T_9c402_row7_col4, #T_9c402_row8_col4, #T_9c402_row9_col4, #T_9c402_row10_col4, #T_9c402_row11_col4, #T_9c402_row12_col4, #T_9c402_row13_col4, #T_9c402_row14_col4, #T_9c402_row15_col4, #T_9c402_row16_col4, #T_9c402_row17_col4, #T_9c402_row18_col4, #T_9c402_row19_col4, #T_9c402_row20_col4, #T_9c402_row21_col4, #T_9c402_row22_col4, #T_9c402_row23_col4, #T_9c402_row24_col4, #T_9c402_row25_col4, #T_9c402_row26_col4, #T_9c402_row27_col4, #T_9c402_row28_col4, #T_9c402_row29_col10 {
#   background-color: #aac2cc;
#   color: #000000;
# }
# #T_9c402_row1_col5, #T_9c402_row2_col5, #T_9c402_row3_col5, #T_9c402_row4_col5, #T_9c402_row6_col5, #T_9c402_row7_col5, #T_9c402_row8_col5, #T_9c402_row8_col29, #T_9c402_row9_col5, #T_9c402_row10_col5, #T_9c402_row11_col5, #T_9c402_row12_col5, #T_9c402_row13_col5, #T_9c402_row14_col5, #T_9c402_row15_col5, #T_9c402_row16_col5, #T_9c402_row17_col5, #T_9c402_row18_col5, #T_9c402_row19_col5, #T_9c402_row20_col5, #T_9c402_row21_col5, #T_9c402_row22_col5, #T_9c402_row23_col5, #T_9c402_row24_col5, #T_9c402_row25_col5, #T_9c402_row26_col5, #T_9c402_row27_col5, #T_9c402_row28_col5 {
#   background-color: #5f65b5;
#   color: #f1f1f1;
# }
# #T_9c402_row1_col7, #T_9c402_row2_col7, #T_9c402_row3_col7, #T_9c402_row4_col7, #T_9c402_row5_col7, #T_9c402_row6_col7, #T_9c402_row8_col7, #T_9c402_row9_col7, #T_9c402_row10_col7, #T_9c402_row11_col7, #T_9c402_row12_col7, #T_9c402_row13_col7, #T_9c402_row14_col7, #T_9c402_row15_col7, #T_9c402_row16_col7, #T_9c402_row17_col7, #T_9c402_row18_col7, #T_9c402_row19_col7, #T_9c402_row20_col7, #T_9c402_row21_col7, #T_9c402_row22_col7, #T_9c402_row23_col7, #T_9c402_row24_col7, #T_9c402_row25_col7, #T_9c402_row26_col7, #T_9c402_row27_col7, #T_9c402_row28_col7 {
#   background-color: #80a5c3;
#   color: #f1f1f1;
# }
# #T_9c402_row1_col8, #T_9c402_row2_col8, #T_9c402_row3_col8, #T_9c402_row4_col8, #T_9c402_row5_col8, #T_9c402_row6_col8, #T_9c402_row7_col8, #T_9c402_row9_col8, #T_9c402_row10_col8, #T_9c402_row11_col8, #T_9c402_row12_col8, #T_9c402_row13_col8, #T_9c402_row14_col8, #T_9c402_row15_col8, #T_9c402_row16_col8, #T_9c402_row17_col8, #T_9c402_row18_col8, #T_9c402_row19_col8, #T_9c402_row20_col8, #T_9c

# %%
plt.figure(figsize=(15,15))
sns.heatmap(cbar=True,data=df.corr(),cmap='tab20b')
plt.show()

# %%
df.keys()
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
X=df.drop(columns={'Class'})
y=df['Class']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)
y_test = y_test.ravel()
y_train = y_train.ravel()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
tree= DecisionTreeClassifier()
tree.fit(X_train,y_train)
y_pred3=tree.predict(X_test)

cm3=confusion_matrix(y_test,y_pred3)
sns.heatmap(cm3,annot=True)

print('Decission Tree accuracy :',accuracy_score(y_test,y_pred3))
# Out:
# Decission Tree accuracy : 0.9992451107756047

# %%
#ANN
# Importing the Keras libraries and packages
from keras.models import Sequential
from keras.layers import Dense

# Initialising the ANN
classifier = Sequential()
classifier.add(Dense(10, activation = 'relu', input_dim = 30))
classifier.add(Dense(10, activation = 'relu'))
classifier.add(Dense(1,  activation = 'sigmoid'))
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
classifier.summary()
# Fitting the ANN to the Training set
history = classifier.fit(X_train, y_train, batch_size = 1000, epochs = 20, validation_data=(X_test, y_test))
# Predicting the Test set results
y_pred5 = classifier.predict(X_test).round()
y_pred5 = (y_pred5 > 0.5)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                310
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 431 (1.68 KB)
# Trainable params: 431 (1.68 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 228/228 [==============================] - 2s 4ms/step - loss: 0.2691 - accuracy: 0.9388 - val_loss: 0.0465 - val_accuracy: 0.9985
# Epoch 2/20
# 228/228 [==============================] - 1s 4ms/step - loss: 0.0225 - accuracy: 0.9982 - val_loss: 0.0123 - val_accuracy: 0.9985
# Epoch 3/20
# 228/228 [==============================] - 1s 3ms/step - loss: 0.0094 - accuracy: 0.9982 - val_loss: 0.0079 - val_accuracy: 0.9985
# Epoch 4/20
# 228/228 [==============================] - 1s 3ms/step - loss: 0.0070 - accuracy: 0.9982 - val_loss: 0.0064 - val_accuracy: 0.9985
# Epoch 5/20
# 228/228 [==============================] - 1s 3ms/step - loss: 0.0060 - accuracy: 0.9982 - val_loss: 0.0056 - val_accuracy: 0.9985
# Epoch 6/20
# 228/228 [==============================] - 1s 3ms/step - loss: 0.0054 - accuracy: 0.9982 - val_loss: 0.0052 - val_accuracy: 0.9985
# Epoch 7/20
# 228/228 [==============================] - 1s 3ms/step - loss: 0.0051 - accuracy: 0.9982 - val_loss: 0.0050 - val_accuracy: 0.9985
# Epoch 8/20
# 228/228 [==============================] - 1s 3ms/step - loss: 0.0049 - accuracy: 0.9982 - val_loss: 0.0049 - val_accuracy: 0.9985
# Epoch 9/20
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0048 - accuracy: 0.9982 - val_loss: 0.0048 - val_accuracy: 0.9985
# Epoch 10/20
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0047 - accuracy: 0.9982 - val_loss: 0.0047 - val_accuracy: 0.9985
# Epoch 11/20
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0045 - accuracy: 0.9982 - val_loss: 0.0046 - val_accuracy: 0.9985
# Epoch 12/20
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0044 - accuracy: 0.9982 - val_loss: 0.0046 - val_accuracy: 0.9985
# Epoch 13/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0043 - accuracy: 0.9982 - val_loss: 0.0045 - val_accuracy: 0.9985
# Epoch 14/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0042 - accuracy: 0.9982 - val_loss: 0.0045 - val_accuracy: 0.9985
# Epoch 15/20
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0041 - accuracy: 0.9982 - val_loss: 0.0044 - val_accuracy: 0.9985
# Epoch 16/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0039 - accuracy: 0.9982 - val_loss: 0.0044 - val_accuracy: 0.9985
# Epoch 17/20
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0038 - accuracy: 0.9982 - val_loss: 0.0041 - val_accuracy: 0.9985
# Epoch 18/20
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 0.0039 - val_accuracy: 0.9993
# Epoch 19/20
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0031 - accuracy: 0.9994 - val_loss: 0.0039 - val_accuracy: 0.9994
# Epoch 20/20
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0030 - accuracy: 0.9994 - val_loss: 0.0038 - val_accuracy: 0.9994
# 1781/1781 [==============================] - 3s 2ms/step

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test).flatten().round()
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
import seaborn as sns
sns.heatmap(cm, annot=True)
#find accuracy
from sklearn.metrics import accuracy_score
print('ANN',accuracy_score(y_test,y_pred))
# find classification report
from sklearn.metrics import f1_score , precision_score , recall_score , classification_report
print('classification_report:',classification_report(y_test,y_pred))
print('f1_score:',f1_score(y_test,y_pred))
print('precision_score:',precision_score(y_test,y_pred))
print('recall_score:',recall_score(y_test,y_pred))
# Out:
# 1781/1781 [==============================] - 3s 1ms/step
# ANN 0.9993504441557529
# classification_report:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56875
#            1       0.78      0.80      0.79        87
#
#     accuracy                           1.00     56962
#    macro avg       0.89      0.90      0.90     56962
# weighted avg       1.00      1.00      1.00     56962
#
# f1_score: 0.7909604519774011
# precision_score: 0.7777777777777778
# recall_score: 0.8045977011494253

# %%
import matplotlib.pyplot as plt
def plot_curve(history , epoch):
    epoch_range = range(1 , epoch+1)
    plt.plot(epoch_range , history.history['accuracy'])
    plt.plot(epoch_range, history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.xlabel('Accuracy')
    plt.ylabel('Epoch')
    plt.legend(['Train','Val'])
    plt.show()

    epoch_range = range(1, epoch + 1)
    plt.plot(epoch_range, history.history['loss'])
    plt.plot(epoch_range, history.history['val_loss'])
    plt.title('model loss')
    plt.xlabel('Loss')
    plt.ylabel('Epoch')
    plt.legend(['Train', 'Val'])
    plt.show()

plot_curve(history , 20)

# %%
from sklearn.ensemble import RandomForestClassifier
RF= RandomForestClassifier()
RF.fit(X_train,y_train)
y_pred4=RF.predict(X_test)
""
cm4=confusion_matrix(y_test,y_pred4)
sns.heatmap(cm4,annot=True)

print('Random Forest accuracy :',accuracy_score(y_test,y_pred4))
# Out:
# Random Forest accuracy : 0.9996137776061234

# %%
from sklearn.metrics import accuracy_score
print('random forest:',accuracy_score(y_test,y_pred4))
# find classification report
from sklearn.metrics import f1_score , precision_score , recall_score
print('f1_score:',f1_score(y_test,y_pred4))
print('precision_score:',precision_score(y_test,y_pred4))
print('recall_score:',recall_score(y_test,y_pred4))
# Out:
# random forest: 0.9996137776061234
# f1_score: 0.860759493670886
# precision_score: 0.9577464788732394
# recall_score: 0.7816091954022989
