# %%
# !gdown --id 1g1-op0fOq0ob6h-LCzL-dclipXR17VTM
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1g1-op0fOq0ob6h-LCzL-dclipXR17VTM
# To: /content/hotel_bookings.csv
# 100% 16.8M/16.8M [00:00<00:00, 136MB/s]

# %% [markdown]
# #**Importing Libraries**

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Read dataset**

# %%
df = pd.read_csv("/content/hotel_bookings.csv", header=0)

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# data info
print('Total Rows:', df.shape[0])
print('Total Columns:', df.shape[1])
df.info(memory_usage = False)
print('\n')

# data describe
df.describe()
# Out:
# Total Rows: 119390
# Total Columns: 32
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
# ...

# %%
# See the difference between 'resort hotel' and 'city hotel'
plt.figure(figsize=(6,4), dpi=150)
sns.countplot(x='hotel', data=df)
# Out:
# <Axes: xlabel='hotel', ylabel='count'>

# %%
canceled_data = df[df["is_canceled"] == 1]

top_10_country = canceled_data["country"].value_counts()[:10]
plt.figure(figsize=(8,8))
plt.title("Top 10 Countries with reservation canceled")
plt.pie(top_10_country, autopct = "%.2f", labels = top_10_country.index)
plt.show()

# %%
# get the number of missing data points per column
missing_values_count = df.isnull().sum()

# look at the # of missing points in the first ten columns
missing_values_count[0:50]
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# how many total missing values do we have?
total_cells = np.product(df.shape)
total_missing = missing_values_count.sum()

# percent of data that is missing
(total_missing/total_cells) * 100
# Out:
# 3.387663330262166

# %%
# Deleting the column of 'company' because it has too many missing value
df.drop('company', axis=1, inplace=True)

# remove all the rows that contain a missing value
df = df.dropna()
df = df.reset_index(drop=True)

df.isna().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# ...

# %% [markdown]
# # **Clean data**

# %% [markdown]
# ### **Explore unique data**

# %%
for col in df.columns:
    if type(df[col][0]) is str and col not in ['reservation_status_date']:
        print("{} : {}".format(col,df[col].unique()))
        print('\n')
# Out:
# hotel : ['Resort Hotel' 'City Hotel']
#
#
# arrival_date_month : ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
#
#
# meal : ['BB' 'FB' 'HB' 'SC' 'Undefined']
#
#
# country : ['GBR' 'PRT' 'USA' 'ESP' 'IRL' 'ROU' 'NOR' 'OMN' 'ARG' 'POL' 'DEU' 'FRA'
#  'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'DNK' 'RUS' 'SWE' 'AUS' 'EST' 'CZE' 'BRA'
#  'FIN' 'MOZ' 'BWA' 'LUX' 'NLD' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR' 'UKR'
#  'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'CYM' 'ZMB' 'ZWE'
#  'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM' 'HRV' 'HKG' 'ISR' 'IRN' 'GEO'
#  'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY' 'KWT' 'NGA' 'MDV' 'VEN'
#  'SVK' 'AGO' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN' 'SYC' 'AZE' 'BHR'
#  'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB' 'CMR' 'MUS' 'COM'
#  'SUR' 'UGA' 'BGR' 'CIV' 'JOR' 'SYR' 'SGP' 'BDI' 'SAU' 'VNM' 'PLW' 'QAT'
#  'EGY' 'PER' 'MLT' 'MWI' 'ISL' 'ECU' 'NPL' 'CPV' 'BHS' 'MAC' 'TGO' 'TWN'
# ...

# %%
# Check for duplicate data
df.duplicated().sum()
# Out:
# 27823

# %%
# Delete duplicate data
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %%
# rename hotel
df.columns = ['Hotel', 'Canceled', 'LeadTime', 'ArrivalDateYear', 'ArrivalDateMonth', 'ArrivalDateWeekNumber','ArrivalDatedayOfMonth', 'StaysInWeekendNights',
              'StaysInWeekNights', 'Adults', 'Children', 'Babies', 'Meal','Country', 'MarketSegment', 'DistributionChannel','IsRepeatGuest', 'PreviousCancellations',
              'PreviousBookingsNotCanceled', 'ReservedRoomType','AssignedRoomType', 'BookingChanges', 'DepositType','agent', 'DaysInWaitingList',
              'CustomerType', 'ADR','RequiredCarParkingSpace', 'TotalOfSpecialRequest','ReservationStatues', 'ReservationStatus']

df.head()
# Out:
#           Hotel  Canceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0  Resort Hotel         0        13             2015             July
# 1  Resort Hotel         0        14             2015             July
# 3  Resort Hotel         0         9             2015             July
# 4  Resort Hotel         1        85             2015             July
# 5  Resort Hotel         1        75             2015             July
#
#    ArrivalDateWeekNumber  ArrivalDatedayOfMonth  StaysInWeekendNights  \
# 0                     27                      1                     0
# 1                     27                      1                     0
# 3                     27                      1                     0
# 4                     27                      1                     0
# 5                     27                      1                     0
#
#    StaysInWeekNights  Adults  ...  BookingChanges  DepositType  agent  \
# ...

# %%
# Identify Continuous and Categorical Variables
def var(hotel):
    unique_list = pd.DataFrame([[i,len(hotel[i].unique())] for i in hotel.columns])
    unique_list.columns = ['name','uniques']

    total_var = set(hotel.columns)
    cat_var = set(unique_list.name[(unique_list.uniques<=12)|
                                   (unique_list.name=='Country')|
                                   (unique_list.name=='Agent')])
    con_var = total_var - cat_var

    return cat_var, con_var

cat_var, con_var = var(df)

print("Continuous Variables (",len(con_var),"):\n",con_var,'\n\n'
        "Categorical Variables(",len(cat_var),"):\n",cat_var)
# Out:
# Continuous Variables ( 12 ):
#  {'PreviousCancellations', 'agent', 'BookingChanges', 'ArrivalDatedayOfMonth', 'ReservationStatus', 'StaysInWeekNights', 'ADR', 'DaysInWaitingList', 'ArrivalDateWeekNumber', 'StaysInWeekendNights', 'PreviousBookingsNotCanceled', 'LeadTime'}
#
# Categorical Variables( 19 ):
#  {'Babies', 'AssignedRoomType', 'Children', 'Canceled', 'DepositType', 'Country', 'ArrivalDateYear', 'Meal', 'MarketSegment', 'CustomerType', 'DistributionChannel', 'IsRepeatGuest', 'RequiredCarParkingSpace', 'ReservationStatues', 'ReservedRoomType', 'TotalOfSpecialRequest', 'Adults', 'Hotel', 'ArrivalDateMonth'}

# %% [markdown]
# ### **Imputing the Outliers (for Continuous Variable)**

# %%
#outliers in continuous variables
df[con_var].describe()
# Out:
# <ipython-input-16-287e4a38b9fd>:2: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df[con_var].describe()
#        PreviousCancellations         agent  BookingChanges  \
# count           75071.000000  75071.000000    75071.000000
# mean                0.019688     93.932784        0.248218
# std                 0.316184    113.111819        0.698098
# min                 0.000000      1.000000        0.000000
# 25%                 0.000000      9.000000        0.000000
# 50%                 0.000000     14.000000        0.000000
# 75%                 0.000000    240.000000        0.000000
# max                26.000000    535.000000       18.000000
#
#        ArrivalDatedayOfMonth  StaysInWeekNights           ADR  \
# count           75071.000000       75071.000000  75071.000000
# mean               15.797818           2.751036    110.199214
# std                 8.845078           2.042798     54.386522
# ...

# %%
#outliers in categorical variables
df[cat_var].describe()
# Out:
# <ipython-input-17-107c4a58a853>:2: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df[cat_var].describe()
#              Babies      Children      Canceled  ArrivalDateYear  \
# count  75071.000000  75071.000000  75071.000000     75071.000000
# mean       0.010510      0.148899      0.299210      2016.225520
# std        0.113361      0.471509      0.457915         0.682752
# min        0.000000      0.000000      0.000000      2015.000000
# 25%        0.000000      0.000000      0.000000      2016.000000
# 50%        0.000000      0.000000      0.000000      2016.000000
# 75%        0.000000      0.000000      1.000000      2017.000000
# max       10.000000     10.000000      1.000000      2017.000000
#
#        IsRepeatGuest  RequiredCarParkingSpace  TotalOfSpecialRequest  \
# count   75071.000000             75071.000000           75071.000000
# ...

# %%
# Creating a boxplot for Outlier detection
features = ['LeadTime', 'StaysInWeekendNights', 'StaysInWeekNights', 'Adults','Children', 'Babies','ADR']
# features = ['ADR', 'LeadTime', 'StaysInWeekendNights']
n = 1
plt.figure(figsize=(16,18))
for feature in features:
    plt.subplot(4,4,n)
    sns.boxplot(df[feature])
    n+=1
    plt.tight_layout()

# %%
df.loc[df.LeadTime                    > 500,'LeadTime'                   ]=500
df.loc[df.DaysInWaitingList           >   0,'DaysInWaitingList'          ]=  1
df.loc[df.StaysInWeekendNights        >=  5,'StaysInWeekendNights'       ]=  5
df.loc[df.Adults                      >   4,'Adults'                     ]=  4
df.loc[df.PreviousBookingsNotCanceled >   0,'PreviousBookingsNotCanceled']=  1
df.loc[df.PreviousCancellations       >   0,'PreviousCancellations'      ]=  1
df.loc[df.StaysInWeekNights           >  10,'StaysInWeekNights'          ]= 10
df.loc[df.BookingChanges              >   5,'BookingChanges'             ]=  5


cat_var = set(list(cat_var) + ['PreviousBookingsNotCanceled','PreviousCancellations'])
con_var = set(df.columns) - cat_var

df[con_var].describe()
# Out:
# <ipython-input-19-ef813e9af31f>:14: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df[con_var].describe()
#               agent  BookingChanges  ArrivalDatedayOfMonth  StaysInWeekNights  \
# count  75071.000000    75071.000000           75071.000000       75071.000000
# mean      93.932784        0.243130              15.797818           2.727351
# std      113.111819        0.639477               8.845078           1.895440
# min        1.000000        0.000000               1.000000           0.000000
# 25%        9.000000        0.000000               8.000000           1.000000
# 50%       14.000000        0.000000              16.000000           2.000000
# 75%      240.000000        0.000000              24.000000           4.000000
# max      535.000000        5.000000              31.000000          10.000000
#
#                 ADR  DaysInWaitingList  ArrivalDateWeekNumber  \
# ...

# %%
df.loc[df.Babies                      >   8,'Babies'                 ] = 0
df.loc[df.RequiredCarParkingSpace     >   5,'RequiredCarParkingSpace'] = 0
df.loc[df.Children                    >   8,'Children'               ] = 0

df[cat_var].describe()
# Out:
# <ipython-input-20-3ddd77c154e8>:5: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df[cat_var].describe()
#              Babies      Children      Canceled  PreviousBookingsNotCanceled  \
# count  75071.000000  75071.000000  75071.000000                 75071.000000
# mean       0.010257      0.148766      0.299210                     0.012681
# std        0.102201      0.470136      0.457915                     0.111896
# min        0.000000      0.000000      0.000000                     0.000000
# 25%        0.000000      0.000000      0.000000                     0.000000
# 50%        0.000000      0.000000      0.000000                     0.000000
# 75%        0.000000      0.000000      1.000000                     0.000000
# max        2.000000      3.000000      1.000000                     1.000000
#
#        ArrivalDateYear  IsRepeatGuest  RequiredCarParkingSpace  \
# ...

# %% [markdown]
# ### **Data Preparation**

# %%
#Combine children and babies together as kids
df['Kids'] = df.Children + df.Babies

#Combine total mumbers by adding kids and adults
df['TotalMembers'] = df.Kids + df.Adults

# %%
#convert the datatypes to string
df['ArrivalDateYear'] = df['ArrivalDateYear'].astype('str')
df['ArrivalDateMonth'] = df['ArrivalDateMonth'].astype('str')
df['ArrivalDatedayOfMonth'] = df['ArrivalDatedayOfMonth'].astype('str')

df['PreviousCancellations'] = df['PreviousCancellations'].astype('str')
df['IsRepeatGuest'] = df['IsRepeatGuest'].astype('str')

# %%
# Convert arrival date to datetime
df['Arrival Date'] = df['ArrivalDatedayOfMonth'] + '-' + df['ArrivalDateMonth'] + '-' + df['ArrivalDateYear']
df['Arrival Date'] = pd.to_datetime(df['Arrival Date'], errors='coerce')

# %%
confirmed_bookings = df[df.PreviousCancellations=='0']

# %%
import datetime as dt
confirmed_bookings['ArrivingMonth'] = df['Arrival Date'].dt.month
final=confirmed_bookings['ArrivingMonth'].value_counts().sort_index()
final
# Out:
# <ipython-input-25-ea8a1464abf2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   confirmed_bookings['ArrivingMonth'] = df['Arrival Date'].dt.month
# 1      3579
# 2      4879
# 3      6239
# 4      6897
# 5      7202
# 6      6974
# 7      9008
# 8     10091
# 9      5701
# 10     5428
# 11     3989
# 12     4049
# Name: ArrivingMonth, dtype: int64

# %% [markdown]
# # **EDA**

# %% [markdown]
# ### **Cancel**

# %%
print('Total Bookings canceled')
print(df.PreviousCancellations.value_counts())
print('\n')
print('Cancelation percentage in both hotels ')
print(df.PreviousCancellations.value_counts(normalize=True))
# Out:
# Total Bookings canceled
# 0    74036
# 1     1035
# Name: PreviousCancellations, dtype: int64
#
#
# Cancelation percentage in both hotels
# 0    0.986213
# 1    0.013787
# Name: PreviousCancellations, dtype: float64

# %% [markdown]
# ### **Country**

# %%
df.Country.value_counts(normalize=True)
# Out:
# PRT    0.261033
# GBR    0.127493
# FRA    0.110842
# ESP    0.089449
# DEU    0.068602
#          ...
# BHS    0.000013
# NPL    0.000013
# MWI    0.000013
# GLP    0.000013
# HND    0.000013
# Name: Country, Length: 174, dtype: float64

# %% [markdown]
# ### **Market Segment**

# %%
df.MarketSegment.value_counts(normalize=True)
# Out:
# Online TA        0.682194
# Offline TA/TO    0.182481
# Direct           0.082349
# Groups           0.044465
# Corporate        0.006873
# Complementary    0.001319
# Aviation         0.000320
# Name: MarketSegment, dtype: float64

# %% [markdown]
# ### **Meal**

# %%
df.Meal.value_counts(normalize=True)
# Out:
# BB           0.756923
# SC           0.122417
# HB           0.111907
# Undefined    0.004795
# FB           0.003956
# Name: Meal, dtype: float64

# %% [markdown]
# ### **Customer Type**

# %%
df.CustomerType.value_counts(normalize=True)
# Out:
# Transient          0.832372
# Transient-Party    0.120033
# Contract           0.041654
# Group              0.005941
# Name: CustomerType, dtype: float64

# %% [markdown]
# ### **Reservation**

# %%
df.ReservationStatues.value_counts(normalize=True)
# Out:
# Check-Out    0.700790
# Canceled     0.288194
# No-Show      0.011016
# Name: ReservationStatues, dtype: float64

# %% [markdown]
# # **Data Visualization**

# %%
#Lets see the correlation
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True,cmap='RdYlGn')
# Out:
# <ipython-input-32-5dda344496ac>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap='RdYlGn')
# <Axes: >

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='ArrivalDateYear', y='LeadTime',hue='PreviousCancellations', data= df, palette='vlag')
plt.title('Arriving Date year, Leadtime and Canceled')
# Out:
# Text(0.5, 1.0, 'Arriving Date year, Leadtime and Canceled')

# %%
# Arrivals in month and year
plt.figure(figsize=(15, 8))
plt.subplot(1, 2, 1)
sns.countplot(x='ArrivalDateYear',hue='Hotel', data=df,palette='husl')
plt.title("Arrivals per year in Both hotels ",fontweight="bold", size=20)
plt.subplot(1, 2, 2)
sns.countplot(data = df, x = 'ArrivalDateMonth')
plt.title('Arrivals per month',fontweight="bold", size=20)
plt.subplots_adjust(right=1.7)

plt.show()

# %%
# Arrivarl Date
plt.figure(figsize=(15,6))

sns.countplot(data = df, x = 'ArrivalDatedayOfMonth', hue='Hotel', palette='Paired')
plt.show()

# %%
from pandas.io.formats.info import DataFrameTableBuilderNonVerbose
plt.figure(figsize=(15, 8))
plt.subplot(1, 2, 1)
sns.countplot(x='TotalMembers',hue='Hotel', data=df, palette='cool')
plt.title("Number of customer in both hotels",fontweight="bold", size=20)


plt.show()

# %%
country_visitors = df[df['PreviousCancellations'] == '0'].groupby(['Country']).size().reset_index(name = 'count')


import plotly.express as px

px.choropleth(country_visitors,
                    locations = "Country",
                    color= "count" ,
                    hover_name= "Country", # column to add to hover information
                    color_continuous_scale="Viridis",
                    title="Home country of visitors")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Market segment
plt.figure(figsize=(15, 8))
plt.subplot(1, 2, 1)
sns.countplot(x='MarketSegment', data=df, palette='rocket')
plt.title('Types of market segment',fontweight="bold", size=20)

plt.subplot(1, 2, 2)
sns.countplot(data = df, x = 'DistributionChannel',  palette='Set1_r')
plt.title('Types of distribution channels',fontweight="bold", size=20)
plt.subplots_adjust(right=1.7)



plt.show()

# %%
# Deposit
plt.figure(figsize=(12, 6))

sns.countplot(data = df, x = 'DepositType',hue='Hotel', palette='cool')
plt.title('Types of Deposit type',fontweight="bold", size=20)


plt.show()

# %%
#Repeat guest

plt.figure(figsize=(8,6))
sns.countplot(data = df, x = 'IsRepeatGuest').set_title('Graph showing whether guest is repeated guest', fontsize = 20)
plt.show()
